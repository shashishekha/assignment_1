# %% [markdown]
# ### 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
f =  open("today.txt",'w')

# %%
f.write(datetime.datetime.now().strftime("%d-%m-%y"))
# Out:
# 8

# %%
f.close()

# %%
f = open('today.txt','r')

# %%
print(f.read())
# Out:
# 10-03-22

# %%
f.close()

# %% [markdown]
# ### 2. Read the text file today.txt into the string today_string

# %%
f = open('today.txt','r')

# %%
today_string = f.read()

# %%
print(today_string)
# Out:
# 10-03-22

# %% [markdown]
# ### 3. Parse the date from today_string.

# %%
from  datetime import datetime
parseData = datetime.strptime(today_string, '%d-%m-%y')

# %%
print(parseData)
# Out:
# 2022-03-10 00:00:00

# %% [markdown]
# ### 4. List the files in your current directory

# %%
import os
for folders , subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# 19.3 MongoDB.7z
# 6 march,2022, pandas.ipynb
# app3.log
# assignment 3.ipynb
# assignment 4.ipynb
# Assignment_2.ipynb
# Assignment_21.ipynb
# Assignment_22.ipynb
# Assignment_23.ipynb
# Assignment_24.ipynb
# Assignment_25.ipynb
# Book1.csv
# Cassandra.ipynb
# cricket.csv
# database 5 feb 2022.ipynb
# glass.data
# ineron.db
# ineuron.db
# joindb.db
# joindb.db-journal
# json_res.csv
# logging.ipynb
# logginggg.ipynb
# NBA.csv
# oops.ipynb
# Pandas.ipynb
# pandas2.ipynb
# Pandas5marchclass.ipynb
# person.db
# person_db
# Programming Assignment 5.ipynb
# Programming Assignment 6.ipynb
# Programming Assignment 7.ipynb
# Programming Assignment 8.ipynb
# Programming Assignment 9.ipynb
# Programming_assignment_1.ipynb
# Programming_assignment_2.ipynb
# Programming_Assignment_3.ipynb
# Programming_assignment_4.ipynb
# spam.py
# sql feb 6, 2022.ipynb
# SQLITE(20FEB,2022), filter,reduce,map.ipynb
# test.log
# test.txt
# test1.txt
# test2.log
# test2.txt
# test3.log
# test4.log
# test43
# ...

# %% [markdown]
# ### 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '19.3 MongoDB',
#  '19.3 MongoDB.7z',
#  '6 march,2022, pandas.ipynb',
#  'app3.log',
#  'assignment 3.ipynb',
#  'assignment 4.ipynb',
#  'Assignment_2.ipynb',
#  'Assignment_21.ipynb',
#  'Assignment_22.ipynb',
#  'Assignment_23.ipynb',
#  'Assignment_24.ipynb',
#  'Assignment_25.ipynb',
#  'bank',
#  'Book1.csv',
#  'Cassandra.ipynb',
#  'cricket.csv',
#  'database 5 feb 2022.ipynb',
#  'glass.data',
#  'ineron.db',
#  'ineuron.db',
#  'joindb.db',
#  'joindb.db-journal',
#  'json_res.csv',
#  'logging.ipynb',
#  'logginggg.ipynb',
#  'loggingI',
#  'ml and datascience projects',
#  'NBA.csv',
#  'ohana-api-master',
#  'oops.ipynb',
#  'Pandas.ipynb',
#  'pandas2.ipynb',
#  'Pandas5marchclass.ipynb',
#  'person.db',
#  'person_db',
#  'Programming Assignment 5.ipynb',
#  'Programming Assignment 6.ipynb',
#  'Programming Assignment 7.ipynb',
#  'Programming Assignment 8.ipynb',
#  'Programming Assignment 9.ipynb',
#  'Programming_assignment_1.ipynb',
# ...

# %% [markdown]
# ### 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time
import random
import datetime

# %%
def process_one():
    print(f'process_one_startime ->{datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'process_one_Endtime -> {datetime.datetime.now()}')

# %%
def process_two():
    print(f'process_two_startime ->{datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'process_two_Endtime -> {datetime.datetime.now()}')

# %%
def process_three():
    print(f'process_three_startime ->{datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'process_three_Endtime -> {datetime.datetime.now()}')

# %%
if __name__ == "__main__":
    p1 = multiprocessing.Process(target=process_one)
    p2 = multiprocessing.Process(target=process_two)
    p3 = multiprocessing.Process(target=process_three)

# %%
p1.start()

# %%
p2.start()

# %%
p3.start()

# %%
p1.join()
p2.join()
p3.join()

# %% [markdown]
# process_one_startime ->2022-03-10 17:33:13.810356
# process_three_startime ->2022-03-10 17:33:13.812292
# process_two_startime ->2022-03-10 17:33:13.812846
# process_three_Endtime -> 2022-03-10 17:33:15.813840
# process_one_Endtime -> 2022-03-10 17:33:16.813544
# process_two_Endtime -> 2022-03-10 17:33:17.817029

# %% [markdown]
# ### 7. Create a date object of your day of birth.

# %%
from datetime import datetime
myDob = datetime.strptime('08/02/99','%d/%m/%y')
print(myDob, type(myDob))
# Out:
# 1999-02-08 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# ### 8. What day of the week was your day of birth?

# %%
from datetime import datetime
myDob = datetime(1999,2,8)
myDob.strftime('%A')
# Out:
# 'Monday'

# %% [markdown]
# ### 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
myDob = datetime.strptime("08/02/99", "%d/%m/%y")
afterAge = myDob-timedelta(10000)
afterAge
# Out:
# datetime.datetime(1971, 9, 23, 0, 0)
